# %% [markdown]
# # <font color ="green">Python : Image Processing</font>

# %% [markdown]
# ## <font color="red">Method 1</font>
# ## <font color = "blue">Using Pillow (PIL) Module</font>

# %%
# importing PIL Module 
from PIL import Image 

#Read Image, which is in the same folder
img = Image.open('./art-globe.jpg')

#Dislpay Image
img.show()

# %% [markdown]
# ## <font color="red">Method 1.2</font>
# ## <font color = "blue">Using Pillow (PIL)with matplotlib Module</font>

# %%
# importing PIL Module 
from PIL import Image 
# importing matplotilib Module
import matplotlib.pyplot as plt

#Read Image, which is in the same folder
img = Image.open('./art-globe.jpg')

# Using matplotlob module to display the image
plt.imshow(img)

# %% [markdown]
# ## <font color="red">Method 2</font>
# ## <font color = "blue">Using matplotlib Module</font>

# %%
# importing matplotlib Module
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#Read the image, wshish is in the same folder
img = mpimg.imread('./art-globe.jpg')

# Display the image
plt.imshow(img)

# %% [markdown]
# ## <font color="red">Method 3</font>
# ## <font color = "blue">Using imageio with matplotlib Module</font>

# %%
# importing imageio Module 
import imageio
# importing matplotlib Module
import matplotlib.pyplot as plt

# Read the image by imageio Module 
img = imageio.imread('./art-globe.jpg')

# Display the image by using matplotlib
plt.imshow(img)

# %% [markdown]
# ## <font color="red">Method 4</font>
# ## <font color = "blue">Using openCV Module</font>

# %%
# importing openCV-pyhton (cv2) Module
import cv2 as CV

# Read the image
img = CV.imread('./art-globe.jpg',1)
# NB: 1 : CV.IMREAD_COLOR = to loads color image, transparancy neglected
# 0: CV.IMREAD_GRAYSCALE = to loads image in grayscale mode
# -1: cv. IMREAD_UNCHANGED = lo loads image including as such alpha channel

# Display image 
cv.imshow('windowTitle', img)

# to display image until you press any in keyboard
cv.waitkey(0)

# to destroy all windows
cv.destroyALLWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7f54634093e4> in <module>
#       9
#      10 # Display image
# ---> 11 cv.imshow('windowTitle', img)
#      12
#      13 # to display image until you press any in keyboard
#
# NameError: name 'cv' is not defined
